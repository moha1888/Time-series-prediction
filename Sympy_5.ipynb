# %%
import sympy as sp
# %matplotlib inline

# %%
sp.__version__
# Out:
# '1.6'

# %%
x = sp.symbols('x')

# %%
f = x**2 - 2*x +1

# %%
sp.pprint(f)
# Out:
#  2
# x  - 2⋅x + 1

# %%
print( 'Evaluate function at x = 2')
print(f.subs(x,2))
# Out:
# Evaluate function at x = 2
# 1

# %% [markdown]
# plotting the functions

# %% [markdown]
# plot the function called f

# %%
p1 = plot(f, show=False)
p1.show()

# %% [markdown]
# power functions

# %%
p2 = plot(x*x, show=False)
p2.show()

# %%
p3 = plot(1/x , show=False)
p3.show()

# %%
p4 = plot(sp.sqrt(x) , show=False)
p4.show()

# %%
p5 = plot(sp.ln(x) , show=False)
p5.show()

# %%
p6 = plot(sp.log(x) , show=False)
p6.show()

# %%
p7 = plot(sp.exp(x) , show=False)
p7.show()

# %%
p8 = plot(4*x+8 , show=False)
p8.show()
